# %% [markdown]
# # SLO TBL Topic Classification Visualizations and Metrics.

# %% [markdown]
# ## Refer to showcase(demo2).ipynb for a sample of all the metrics and visualizations for each Classifier that can be outputted to console with all debug and toggle variables enabled.

# %% [markdown]
# ## 5-fold Cross Validation Accuracy and Mean Accuracy over 1000 iterations of randomized training and test set splitting of the input feature and target label sets.

# %% [markdown]
# ### Note: Values can vary per execution of slo_topic_classification_v2-0.py

# %% [raw]
# D:\Dropbox\cs344-ai\venv3.6-64bit\Scripts\python.exe D:/Dropbox/cs344-ai/cs344/Project/slo_topic_classification_v2-0.py
# DEBUG:root:Multinomial Naive Bayes:
# DEBUG:root:Cross validated metrics (5-fold cross validation):
# DEBUG:root:Accuracy: 0.49 (+/- 0.03)
# DEBUG:root:
#
# DEBUG:root:Multinomial Naive Bayes Classifier:
# DEBUG:root:Mean accuracy over 1000 iterations is: 0.49407608695652117
# DEBUG:root:
#
# D:\Dropbox\cs344-ai\venv3.6-64bit\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:603: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning)
# DEBUG:root:Stochastic Gradient Descent:
# DEBUG:root:Cross validated metrics (5-fold cross validation):
# DEBUG:root:Accuracy: 0.49 (+/- 0.02)
# DEBUG:root:
#
# DEBUG:root:Stochastic Gradient Descent Classifier:
# DEBUG:root:Mean accuracy over 1000 iterations is: 0.4977173913043483
# DEBUG:root:
#
# DEBUG:root:Support Vector Classification:
# DEBUG:root:Cross validated metrics (5-fold cross validation):
# DEBUG:root:Accuracy: 0.54 (+/- 0.04)
# DEBUG:root:
#
# DEBUG:root:Support Vector Classification Classifier:
# DEBUG:root:Mean accuracy over 1000 iterations is: 0.5331739130434798
# DEBUG:root:
#
# DEBUG:root:Linear Support Vector Classification:
# DEBUG:root:Cross validated metrics (5-fold cross validation):
# DEBUG:root:Accuracy: 0.49 (+/- 0.02)
# DEBUG:root:
#
# DEBUG:root:Linear Support Vector Classification Classifier:
# DEBUG:root:Mean accuracy over 1000 iterations is: 0.5186086956521752
# DEBUG:root:
#
# DEBUG:root:KNeighbor:
# DEBUG:root:Cross validated metrics (5-fold cross validation):
# DEBUG:root:Accuracy: 0.41 (+/- 0.09)
# DEBUG:root:
#
# DEBUG:root:KNeighbor Classifier:
# DEBUG:root:Mean accuracy over 1000 iterations is: 0.5167934782608703
# DEBUG:root:
#
# DEBUG:root:Decision Tree:
# DEBUG:root:Cross validated metrics (5-fold cross validation):
# DEBUG:root:Accuracy: 0.53 (+/- 0.10)
# DEBUG:root:
#
# DEBUG:root:Decision Tree Classifier:
# DEBUG:root:Mean accuracy over 1000 iterations is: 0.5338586956521746
# DEBUG:root:
#
# DEBUG:root:Multi Layer Perceptron Neural Network:
# DEBUG:root:Cross validated metrics (5-fold cross validation):
# DEBUG:root:Accuracy: 0.50 (+/- 0.01)
# DEBUG:root:
#
# DEBUG:root:Multi Layer Perceptron Neural Network Classifier:
# DEBUG:root:Mean accuracy over 1000 iterations is: 0.49032608695652113
# DEBUG:root:
#
# DEBUG:root:Logistic Regression:
# DEBUG:root:Cross validated metrics (5-fold cross validation):
# DEBUG:root:Accuracy: 0.52 (+/- 0.11)
# DEBUG:root:
#
# DEBUG:root:Logistic Regression Classifier:
# DEBUG:root:Mean accuracy over 1000 iterations is: 0.504467391304348
# DEBUG:root:
#
#
# Process finished with exit code 0

# %% [markdown]
# ## Input feature and target labels.
#
# ### Note: Two seperate dataframes combined into one dataframe from the provided labeled datasets.

# %% [raw]
# D:\Dropbox\cs344-ai\venv3.6-64bit\Scripts\python.exe D:/Dropbox/cs344-ai/cs344/Project/slo_topic_classification_v2-0.py
# DEBUG:root:
#
# DEBUG:root:The shape of our SLO dataframe 1:
# DEBUG:root:(32, 2)
# DEBUG:root:
#
# DEBUG:root:The columns of our SLO dataframe 1:
# DEBUG:root:<bound method NDFrame.head of                                                 Tweet            SLO
# 6    slomention slomention absolutely right  i get...         social
# 17  labor official quote “the adani mine is not in...         social
# 15  now lean putting on the pressure within slomen...         social
# 25  there are antiadani slogans on basically every...         social
# 12   slomention good news everyoneits now cheaper ...       economic
# ..                                                ...            ...
# 0    slomention fun fact larry anthonythe national...         social
# 5    slomention slomention s message to slomention...       economic
# 18   slomention slomention absolutely right  i get...         social
# 30   slomention jobs amp growth slohashtag imo ada...  environmental
# 20   slomention whats going on here slohashtag  re...         social
#
# [32 rows x 2 columns]>
# DEBUG:root:
#
# DEBUG:root:
#
# DEBUG:root:The shape of our SLO dataframe 2:
# DEBUG:root:(245, 2)
# DEBUG:root:
#
# DEBUG:root:The columns of our SLO dataframe 2:
# DEBUG:root:<bound method NDFrame.head of                                                  Tweet            SLO
# 226   slomention just had a chat with fella from st...       economic
# 43    slomention adani accused former environment m...         social
# 0     slomention from the archive  shenhua mine the...         social
# 112   slomention george brandis the best chance for...         social
# 210   slomention india cancels four major new coal ...       economic
# ..                                                 ...            ...
# 180   slomention for slomention farmers r anti nati...         social
# 188   slomention buffoon slomention deletes tweet a...         social
# 22    slomention solar has won even if slohashtag w...         social
# 225  australiagt bhp coal boss mike henry eyes 820m...       economic
# 30    slomention water resources dont understand bo...  environmental
#
# [245 rows x 2 columns]>
# DEBUG:root:
#
# DEBUG:root:
#
# DEBUG:root:The Tweets in our input feature:
# DEBUG:root:0       slomention slomention absolutely right  i get...
# 1      labor official quote “the adani mine is not in...
# 2      now lean putting on the pressure within slomen...
# 3      there are antiadani slogans on basically every...
# 4       slomention good news everyoneits now cheaper ...
#                              ...
# 272     slomention for slomention farmers r anti nati...
# 273     slomention buffoon slomention deletes tweet a...
# 274     slomention solar has won even if slohashtag w...
# 275    australiagt bhp coal boss mike henry eyes 820m...
# 276     slomention water resources dont understand bo...
# Name: Tweet, Length: 277, dtype: object
# DEBUG:root:
#
# DEBUG:root:SLO TBL topic classification label for each Tweet:
# DEBUG:root:0             social
# 1             social
# 2             social
# 3             social
# 4           economic
#            ...
# 272           social
# 273           social
# 274           social
# 275         economic
# 276    environmental
# Name: SLO, Length: 277, dtype: object
# DEBUG:root:
#
#
# Process finished with exit code 0

# %% [markdown]
# ## 5-fold Cross Validation Accuracy and Mean Accuracy over 1000 iterations of randomized training and test set splitting of the input feature and target label sets.  Also included is the count of the TBL topic classification prediction results on the 650k+ Tweet dataset used for stance classification in the prior summer's research.

# %% [markdown]
# ### Note: Did not add toggles to turn on/off the printing of cross validation metrics and mean accuracy over N iterations so those are always outputted to the console.

# %% [raw]
# D:\Dropbox\cs344-ai\venv3.6-64bit\Scripts\python.exe D:/Dropbox/cs344-ai/cs344/Project/slo_topic_classification_v2-0.py
# DEBUG:root:Multinomial Naive Bayes:
# DEBUG:root:Cross validated metrics (5-fold cross validation):
# DEBUG:root:Accuracy: 0.47 (+/- 0.04)
# DEBUG:root:
#
# DEBUG:root:Multinomial Naive Bayes Classifier:
# DEBUG:root:Mean accuracy over 1000 iterations is: 0.4936739130434772
# DEBUG:root:
#
# DEBUG:root:Prediction statistics using Multinomial Naive Bayes Classifier:
# DEBUG:root:The number of Tweets identified as social is :655448
# DEBUG:root:The % of Tweets identified as social in the entire dataset is: 99.46371828062071
# DEBUG:root:The number of Tweets identified as economic is :3534
# DEBUG:root:The % of Tweets identified as economic in the entire dataset is: 0.536281719379285
# DEBUG:root:The number of Tweets identified as environmental is :0
# DEBUG:root:The % of Tweets identified as environmental in the entire dataset is: 0.0
# DEBUG:root:
#
# D:\Dropbox\cs344-ai\venv3.6-64bit\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:603: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning)
# DEBUG:root:Stochastic Gradient Descent:
# DEBUG:root:Cross validated metrics (5-fold cross validation):
# DEBUG:root:Accuracy: 0.52 (+/- 0.05)
# DEBUG:root:
#
# DEBUG:root:Stochastic Gradient Descent Classifier:
# DEBUG:root:Mean accuracy over 1000 iterations is: 0.49460869565217397
# DEBUG:root:
#
# DEBUG:root:Prediction statistics using Stochastic Gradient Descent Classifier:
# DEBUG:root:The number of Tweets identified as social is :650950
# DEBUG:root:The % of Tweets identified as social in the entire dataset is: 98.78115031973559
# DEBUG:root:The number of Tweets identified as economic is :7796
# DEBUG:root:The % of Tweets identified as economic in the entire dataset is: 1.1830368659538502
# DEBUG:root:The number of Tweets identified as environmental is :236
# DEBUG:root:The % of Tweets identified as environmental in the entire dataset is: 0.0358128143105578
# DEBUG:root:
#
# DEBUG:root:Support Vector Classification:
# DEBUG:root:Cross validated metrics (5-fold cross validation):
# DEBUG:root:Accuracy: 0.53 (+/- 0.08)
# DEBUG:root:
#
# DEBUG:root:Support Vector Classification Classifier:
# DEBUG:root:Mean accuracy over 1000 iterations is: 0.5350978260869586
# DEBUG:root:
#
# DEBUG:root:Prediction statistics using Support Vector Classification Classifier:
# DEBUG:root:The number of Tweets identified as social is :622636
# DEBUG:root:The % of Tweets identified as social in the entire dataset is: 94.48452309774774
# DEBUG:root:The number of Tweets identified as economic is :35280
# DEBUG:root:The % of Tweets identified as economic in the entire dataset is: 5.353712241002031
# DEBUG:root:The number of Tweets identified as environmental is :1066
# DEBUG:root:The % of Tweets identified as environmental in the entire dataset is: 0.16176466125023142
# DEBUG:root:
#
# DEBUG:root:Linear Support Vector Classification:
# DEBUG:root:Cross validated metrics (5-fold cross validation):
# DEBUG:root:Accuracy: 0.57 (+/- 0.04)
# DEBUG:root:
#
# DEBUG:root:Linear Support Vector Classification Classifier:
# DEBUG:root:Mean accuracy over 1000 iterations is: 0.5152173913043485
# DEBUG:root:
#
# DEBUG:root:Prediction statistics using Linear Support Vector Classification Classifier:
# DEBUG:root:The number of Tweets identified as social is :542718
# DEBUG:root:The % of Tweets identified as social in the entire dataset is: 82.35702947880216
# DEBUG:root:The number of Tweets identified as economic is :115882
# DEBUG:root:The % of Tweets identified as economic in the entire dataset is: 17.58500232176296
# DEBUG:root:The number of Tweets identified as environmental is :382
# DEBUG:root:The % of Tweets identified as environmental in the entire dataset is: 0.05796819943488593
# DEBUG:root:
#
# DEBUG:root:KNeighbor:
# DEBUG:root:Cross validated metrics (5-fold cross validation):
# DEBUG:root:Accuracy: 0.49 (+/- 0.06)
# DEBUG:root:
#
# DEBUG:root:KNeighbor Classifier:
# DEBUG:root:Mean accuracy over 1000 iterations is: 0.5165217391304354
# DEBUG:root:
#
# DEBUG:root:Prediction statistics using KNeighbor Classifier:
# DEBUG:root:The number of Tweets identified as social is :617282
# DEBUG:root:The % of Tweets identified as social in the entire dataset is: 93.67205781038025
# DEBUG:root:The number of Tweets identified as economic is :38644
# DEBUG:root:The % of Tweets identified as economic in the entire dataset is: 5.86419659414066
# DEBUG:root:The number of Tweets identified as environmental is :3056
# DEBUG:root:The % of Tweets identified as environmental in the entire dataset is: 0.46374559547908745
# DEBUG:root:
#
# DEBUG:root:Decision Tree:
# DEBUG:root:Cross validated metrics (5-fold cross validation):
# DEBUG:root:Accuracy: 0.56 (+/- 0.16)
# DEBUG:root:
#
# DEBUG:root:Decision Tree Classifier:
# DEBUG:root:Mean accuracy over 1000 iterations is: 0.5341956521739141
# DEBUG:root:
#
# DEBUG:root:Prediction statistics using Decision Tree Classifier:
# DEBUG:root:The number of Tweets identified as social is :612703
# DEBUG:root:The % of Tweets identified as social in the entire dataset is: 92.97719816322753
# DEBUG:root:The number of Tweets identified as economic is :46279
# DEBUG:root:The % of Tweets identified as economic in the entire dataset is: 7.022801836772476
# DEBUG:root:The number of Tweets identified as environmental is :0
# DEBUG:root:The % of Tweets identified as environmental in the entire dataset is: 0.0
# DEBUG:root:
#
# DEBUG:root:Multi Layer Perceptron Neural Network:
# DEBUG:root:Cross validated metrics (5-fold cross validation):
# DEBUG:root:Accuracy: 0.50 (+/- 0.02)
# DEBUG:root:
#
# DEBUG:root:Multi Layer Perceptron Neural Network Classifier:
# DEBUG:root:Mean accuracy over 1000 iterations is: 0.48871739130434705
# DEBUG:root:
#
# DEBUG:root:Prediction statistics using Multi Layer Perceptron Neural Network Classifier:
# DEBUG:root:The number of Tweets identified as social is :658982
# DEBUG:root:The % of Tweets identified as social in the entire dataset is: 100.0
# DEBUG:root:The number of Tweets identified as economic is :0
# DEBUG:root:The % of Tweets identified as economic in the entire dataset is: 0.0
# DEBUG:root:The number of Tweets identified as environmental is :0
# DEBUG:root:The % of Tweets identified as environmental in the entire dataset is: 0.0
# DEBUG:root:
#
# DEBUG:root:Logistic Regression:
# DEBUG:root:Cross validated metrics (5-fold cross validation):
# DEBUG:root:Accuracy: 0.52 (+/- 0.04)
# DEBUG:root:
#
# DEBUG:root:Logistic Regression Classifier:
# DEBUG:root:Mean accuracy over 1000 iterations is: 0.5075326086956524
# DEBUG:root:
#
# DEBUG:root:Prediction statistics using Logistic Regression Classifier:
# DEBUG:root:The number of Tweets identified as social is :536506
# DEBUG:root:The % of Tweets identified as social in the entire dataset is: 81.41436336652595
# DEBUG:root:The number of Tweets identified as economic is :114141
# DEBUG:root:The % of Tweets identified as economic in the entire dataset is: 17.320806941616006
# DEBUG:root:The number of Tweets identified as environmental is :8335
# DEBUG:root:The % of Tweets identified as environmental in the entire dataset is: 1.2648296918580477
# DEBUG:root:
#
#
# Process finished with exit code 0
